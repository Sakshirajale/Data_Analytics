# %% [markdown]
# # File=>
# a collection of data that store in computer

# %% [markdown]
# # File Handling
# the process of storing, accessing, and manipulating data in a file using a program

# %%
# Process of file handling
#=>Open file
#=>Perform Operations
#=>Close file-
#default mode=> read and text

# %%
pwd
# Out:
# 'C:\\Users\\ACER\\Data_Analytics_Godrej'

# %%
open("saturday.txt",mode="r")   #doesn't exist file in working directory
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 open("saturday.txt",mode="r")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'saturday.txt'

# %%
open("saturday.txt",mode="w") #write mode is truncate the file and create new file
#open file
# Out:
# <_io.TextIOWrapper name='saturday.txt' mode='w' encoding='cp1252'>

# %%
pwd   # check working directory
# Out:
# 'C:\\Users\\ACER\\Data_Analytics_Godrej'

# %%
open("saturday.txt")
# Out:
# <_io.TextIOWrapper name='saturday.txt' mode='r' encoding='cp1252'>

# %%
f=open("saturday.txt")

# %%
f
# Out:
# <_io.TextIOWrapper name='saturday.txt' mode='r' encoding='cp1252'>

# %%
type(f) #perform operation
# Out:
# _io.TextIOWrapper

# %%
#closing file
f.close()

# %%
try:
    f=open("saturday.txt")
finally:
    f.close           #finally=> whatever code write down in finally then it always execute

# %%
f=open("saturday.txt")
f.write("Hello Everyone!!!!")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[23], line 2
#       1 f=open("saturday.txt")
# ----> 2 f.write("Hello Everyone!!!!")
#
# UnsupportedOperation: not writable

# %%
try:
    f=open("saturday.txt")
    f.write("Hello Everyone!!!!")
finally:
    print("Finally executed!!!!")
    f.close
# Out:
# Finally executed!!!!
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[26], line 3
#       1 try:
#       2     f=open("saturday.txt")
# ----> 3     f.write("Hello Everyone!!!!")
#       4 finally:
#       5     print("Finally executed!!!!")
#
# UnsupportedOperation: not writable

# %%
try:
    f=open("saturday.txt")
    f.write("Hello Everyone!!!!")
except:
    print("seems some issue is there !!!")
finally:
    #by default it always execute
    print("Finally executed!!!!")
    f.close
# Out:
# seems some issue is there !!!
# Finally executed!!!!

# %%
try:
    f=open("saturday.txt")
    f.write("Hello Everyone!!!!")
except:
    print("seems some issue is there !!!")
except:
    print("HI")
finally:
    #by default it always execute
    print("Finally executed!!!!")
    f.close
# Out:
#   Cell In[29], line 4
#     except:
#     ^
# SyntaxError: default 'except:' must be last

# %%
#another method to close file
with open("saturday.txt",mode="w") as f:
    f.write("This is First Line\n")
    f.write("This is second Line\n")
    f.write("This is Third Line\n\n")
    f.write("This is last Line\n")

# %%
f=open("saturday.txt")

# %%
f
# Out:
# <_io.TextIOWrapper name='saturday.txt' mode='r' encoding='cp1252'>

# %%
#Read content of file
f.read()
# Out:
# 'This is First Line\nThis is second Line\nThis is Third Line\n\nThis is last Line\n'

# %%
f.close()

# %%
f=open("saturday.txt")
for c in f.read():   #print character by character
    print(c)
# Out:
# T
# h
# i
# s
#
# i
# s
#
# F
# i
# r
# s
# t
#
# L
# i
# n
# e
#
#
# T
# h
# i
# s
#
# i
# s
#
# s
# e
# c
# o
# n
# d
#
# L
# i
# n
# e
#
#
# T
# h
# i
# s
#
# i
# s
#
# T
# h
# i
# r
# d
#
# L
# i
# n
# e
#
#
#
#
# T
# h
# i
# s
#
# i
# s
#
# l
# a
# s
# t
#
# L
# i
# n
# e

# %%
f.close()

# %%
f=open("saturday.txt")
f.read()
# Out:
# 'This is First Line\nThis is second Line\nThis is Third Line\n\nThis is last Line\n'

# %%
f.read()
# Out:
# ''

# %%
#which position in pointing in point
f.tell()
# Out:
# 82

# %%
f.seek(0)    #get an positon back. whatever you go to back they back it
# Out:
# 0

# %%
f.read()
# Out:
# 'This is First Line\nThis is second Line\nThis is Third Line\n\nThis is last Line\n'

# %%
f.read(10)  #
# Out:
# 'This is Fi'

# %%
f.tell()
# Out:
# 10

# %%
f.read()
# Out:
# 'rst Line\nThis is second Line\nThis is Third Line\n\nThis is last Line\n'

# %%
f.tell()
# Out:
# 82

# %%
f.seek(20)
# Out:
# 20

# %%
f.tell()
# Out:
# 20

# %%
f.read(5)
# Out:
# 'This '

# %%
f.tell()
# Out:
# 25

# %%
for c in f.read():
    print(c,end=' ')
# Out:
# i s   s e c o n d   L i n e
#  T h i s   i s   T h i r d   L i n e
#
#  T h i s   i s   l a s t   L i n e

# %%
f.seek(0)
for c in f.read():
    print(c,end='')
# Out:
# This is First Line
# This is second Line
# This is Third Line
#
# This is last Line

# %%
f.seek(0)
for c in f.read():
    print(c,end='*')
f.close()
# Out:
# T*h*i*s* *i*s* *F*i*r*s*t* *L*i*n*e*
# *T*h*i*s* *i*s* *s*e*c*o*n*d* *L*i*n*e*
# *T*h*i*s* *i*s* *T*h*i*r*d* *L*i*n*e*
# *
# *T*h*i*s* *i*s* *l*a*s*t* *L*i*n*e*
# *

# %%
f=open("saturday.txt")

# %%
f.readline()   #it used to execute line by line #read 1st line
# Out:
# 'This is First Line\n'

# %%
f.readline()  #read 2nd line
# Out:
# 'This is second Line\n'

# %%
f.readline()
# Out:
# 'This is Third Line\n'

# %%
f.readline()
# Out:
# '\n'

# %%
f.readline()
# Out:
# 'This is last Line\n'

# %%
f.readline() [2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 f.readline() [2]
#
# IndexError: string index out of range

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines() [2]
# Out:
# 'This is Third Line\n'

# %%
f.readlines()
# Out:
# []

# %%
f=open("saturday.txt")
for line in f.readlines():
    print(line)
# Out:
# This is First Line
#
# This is second Line
#
# This is Third Line
#
#
#
# This is last Line

# %%
f=open("saturday.txt")
for line in f.readlines():
    print(line,end='')
# Out:
# This is First Line
# This is second Line
# This is Third Line
#
# This is last Line

# %%
data=['a','b','c','d']
for i in data:
    data.append(i.upper())
    break
print(data)
# Out:
# ['a', 'b', 'c', 'd', 'A']

# %%
f=open("saturday.txt",mode="a")   #a=> append
f.write("Hello Everyone you are really good people!!!")
# Out:
# 44

# %%
f
# Out:
# <_io.TextIOWrapper name='saturday.txt' mode='a' encoding='cp1252'>

# %%
f.close()

# %%
f=open("s1.txt","a")

# %%
f.close()

# %% [markdown]
# # Matplot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,10,5)

# %%
y=x**2

# %%
x
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
y
# Out:
# array([  0.  ,   6.25,  25.  ,  56.25, 100.  ])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title("Graph of X vs Y")
plt.xlabel("This is x value")
plt.ylabel("This is y value")
# Out:
# Text(0, 0.5, 'This is y value')

# %%
plt.plot(x,y,"black")
plt.title("Graph of X vs Y")
plt.xlabel("This is x value")
plt.ylabel("This is y value")
# Out:
# Text(0, 0.5, 'This is y value')

# %%
plt.plot(x,y,"r*-")
plt.title("Graph of X vs Y")
plt.xlabel("This is x value")
plt.ylabel("This is y value")
# Out:
# Text(0, 0.5, 'This is y value')

# %%
plt.plot(x,y,"g*-")
plt.title("Graph of X Vs Y")
plt.xlabel("This is X Value")
plt.ylabel("This is Y Value")
plt.show()

# %%
# !pip install folium
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 get_ipython().system('pip install folium')
#
# File ~\anaconda3\Lib\site-packages\ipykernel\zmqshell.py:655, in ZMQInteractiveShell.system_piped(self, cmd)
#     653         if path is not None:
#     654             cmd = f"pushd {path} &&{cmd}"
# --> 655         self.user_ns["_exit_code"] = system(cmd)
#     656 else:
#     657     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124, in system(cmd)
#     122 if path is not None:
#     123     cmd = '"pushd %s &&"%s' % (path, cmd)
# --> 124 return process_handler(cmd, _system_body)
#
# File ~\anaconda3\Lib\site-packages\IPython\utils\_process_common.py:77, in process_handler(cmd, callback, stderr)
# ...

# %%
# !pip install --upgrade ipykernel
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 get_ipython().system('pip install --upgrade ipykernel')
#
# File ~\anaconda3\Lib\site-packages\ipykernel\zmqshell.py:655, in ZMQInteractiveShell.system_piped(self, cmd)
#     653         if path is not None:
#     654             cmd = f"pushd {path} &&{cmd}"
# --> 655         self.user_ns["_exit_code"] = system(cmd)
#     656 else:
#     657     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124, in system(cmd)
#     122 if path is not None:
#     123     cmd = '"pushd %s &&"%s' % (path, cmd)
# --> 124 return process_handler(cmd, _system_body)
#
# File ~\anaconda3\Lib\site-packages\IPython\utils\_process_common.py:77, in process_handler(cmd, callback, stderr)
# ...

# %%
import os
os.chdir('C://Users//ACER//Data_Analytics_Godrej')  # Change to a valid directory path

# %%
pwd
# Out:
# 'C:\\Users\\ACER\\Data_Analytics_Godrej'

# %%
# !pip install pyttsx3
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 get_ipython().system('pip install pyttsx3')
#
# File ~\anaconda3\Lib\site-packages\ipykernel\zmqshell.py:655, in ZMQInteractiveShell.system_piped(self, cmd)
#     653         if path is not None:
#     654             cmd = f"pushd {path} &&{cmd}"
# --> 655         self.user_ns["_exit_code"] = system(cmd)
#     656 else:
#     657     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~\anaconda3\Lib\site-packages\IPython\utils\_process_win32.py:124, in system(cmd)
#     122 if path is not None:
#     123     cmd = '"pushd %s &&"%s' % (path, cmd)
# --> 124 return process_handler(cmd, _system_body)
#
# File ~\anaconda3\Lib\site-packages\IPython\utils\_process_common.py:77, in process_handler(cmd, callback, stderr)
# ...

# %%
import pyttsx3
engine=pyttsx3.init()
engine.say("All of you are really good participants but everyone needs practice!")
engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 import pyttsx3
#       2 engine=pyttsx3.init()
#       3 engine.say("All of you are really good participants but everyone needs practice!")
#
# ModuleNotFoundError: No module named 'pyttsx3'

# %%
mport pyttsx3
engine=pyttsx3.init()
 
""" RATE"""
rate = engine.getProperty('rate')   # getting details of current speaking rate
print (rate)                        #printing current voice rate
engine.setProperty('rate', 200)     # setting up new voice rate
 
engine.say("All of you are really good participants but everyone needs practice!")
engine.runAndWait()
# Out:
#   Cell In[60], line 1
#     mport pyttsx3
#           ^
# SyntaxError: invalid syntax

# %%
import pyttsx3
engine=pyttsx3.init()
 
"""VOICE"""
voices = engine.getProperty('voices')       #getting details of current voice
#engine.setProperty('voice', voices[0].id)  #changing index, changes voices. o for male
engine.setProperty('voice', voices[1].id)   #changing index, changes voices. 1 for female
 
""" RATE"""
rate = engine.getProperty('rate')   # getting details of current speaking rate
print (rate)                        #printing current voice rate
engine.setProperty('rate', 200)     # setting up new voice rate
 
engine.say("All of you are really good participants but everyone needs practice!")
engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 import pyttsx3
#       2 engine=pyttsx3.init()
#       4 """VOICE"""
#
# ModuleNotFoundError: No module named 'pyttsx3'

# %%
##Question test

# %%
print (2**3 + (5 + 6)**(1 + 1))
# Out:
# 129

# %%
def func(): 
  global value 
  value = "Local"

value = "Global" 
func() 
print(value)
# Out:
# Local

# %%
def solve(a): 
   a = [1, 3, 5] 
a = [2, 4, 6] 
print(a) 
solve(a) 
print(a)
# Out:
# [2, 4, 6]
# [2, 4, 6]

# %%
def solve(a, b): 
   return b if a == 0 else solve(b % a, a) 
print(solve(20, 50))
# Out:
# 10

# %%
count = 0 
while(True):
   if count % 3 == 0:
      print(count, end = " ")
   if(count > 15):
      break;
   count += 1
# Out:
# 0 3 6 9 12 15

# %%
a = [[], "abc", [0], 1, 0] 
print(list(filter(bool, a)))
# Out:
# ['abc', [0], 1]

# %%
a = [1, 2, 3, 4] 
b = [3, 4, 5, 6] 
c = [x for x in a if x not in b] 
print(c)
# Out:
# [1, 2]

# %%
s1 = {1, 2, 3, 4, 5} 
s2 = {2, 4, 6} 
print(s1 ^ s2)
# Out:
# {1, 3, 5, 6}

# %%
a = 2.19 
b = 3.999999 
c = -3.30 
print(int(a), floor(b), ceil(c), fabs(c))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 4
#       2 b = 3.999999
#       3 c = -3.30
# ----> 4 print(int(a), floor(b), ceil(c), fabs(c))
#
# NameError: name 'floor' is not defined

# %%
def tester(**kwargs): 
   for key, value in kwargs.items(): 
     print(key, value, end = " ") 
tester(Sunday = 1, Monday = 2, Tuesday = 3, Wednesday = 4)
# Out:
# Sunday 1 Monday 2 Tuesday 3 Wednesday 4

# %%
def tester(*argv): 
   for arg in argv: 
      print(arg, end = ' ') 
tester('Sunday', 'Monday', 'Tuesday', 'Wednesday')
# Out:
# Sunday Monday Tuesday Wednesday

# %%
square = lambda x: x ** 2 
a = [] 
for i in range(5): 
   a.append(square(i)) 
print(a)
# Out:
# [0, 1, 4, 9, 16]

# %%
a = "4, 5" 
nums = a.split(',') 
x, y = nums 
int_prod = int(x) * int(y) 
print(int_prod)
# Out:
# 20

# %%
word = "Python Programming" 
n = len(word) 
word1 = word.upper() 
word2 = word.lower() 
converted_word = "" 
for i in range(n): 
    if i % 2 == 0: 
       converted_word += word2[i] 
    else: 
        converted_word += word1[i] 
        print(converted_word)
# Out:
# pY
# pYtH
# pYtHoN
# pYtHoN P
# pYtHoN PrO
# pYtHoN PrOgR
# pYtHoN PrOgRaM
# pYtHoN PrOgRaMmI
# pYtHoN PrOgRaMmInG

# %%
a = {'Hello':'World', 'First': 1} 
b = {val: k for k , val in a.items()} 
print(b)
# Out:
# {'World': 'Hello', 1: 'First'}

# %%
dict1 = {'first' : 'sunday', 'second' : 'monday'} 
dict2 = {1: 3, 2: 4} 
dict1.update(dict2) 
print(dict1)
# Out:
# {'first': 'sunday', 'second': 'monday', 1: 3, 2: 4}

# %%
numbers = (4, 7, 19, 2, 89, 45, 72, 22) 
sorted_numbers = sorted(numbers) 
odd_numbers = [x for x in sorted_numbers if x % 2 != 0] 
print(odd_numbers)
# Out:
# [7, 19, 45, 89]

# %%
def check(a): 
     print("Even" if a % 2 == 0 else "Odd") 
check(12)
# Out:
# Even

# %%
numbers = (4, 7, 19, 2, 89, 45, 72, 22) 
sorted_numbers = sorted(numbers) 
even = lambda a: a % 2 == 0 
even_numbers = filter(even, sorted_numbers) 
print(type(even_numbers))
# Out:
# <class 'filter'>

# %%
def thrive(n): 
     if n % 15 == 0: 
         print("thrive", end = “ ”) 
     elif n % 3 != 0 and n % 5 != 0: 
        print("neither", end = “ ”) 
     elif n % 3 == 0: 
       print("three", end = “ ”) 
     elif n % 5 == 0: 
       print("five", end = “ ”) 
thrive(35) 
thrive(56) 
thrive(15) 
thrive(39)
# Out:
#   Cell In[87], line 3
#     print("thrive", end = “ ”)
#                           ^
# SyntaxError: invalid character '“' (U+201C)

# %%
numbers = (4, 7, 19, 2, 89, 45, 72, 22) 
sorted_numbers = sorted(numbers) 
print(sorted_numbers)
# Out:
# [2, 4, 7, 19, 22, 45, 72, 89]

# %%
a = [1, 2, 3, 4, 5] 
sum = 0 
for ele in a: 
   sum += ele 
print(sum)
# Out:
# 15

# %%
print(type(5 / 2)) 
print(type(5 // 2))
# Out:
# <class 'float'>
# <class 'int'>

# %%
a = [1, 2, 3] 
a = tuple(a) 
a[0] = 2 
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 3
#       1 a = [1, 2, 3]
#       2 a = tuple(a)
# ----> 3 a[0] = 2
#       4 print(a)
#
# TypeError: 'tuple' object does not support item assignment

# %%
var = 10 
print(type(var)) 
var = "Hello" 
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#Test Finishedd

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2
plt.subplot(1,2,1)
plt.plot(x,y,"g--")
plt.subplot(1,2,2)
plt.plot(y,x,'r*-')

# %%
fig=plt.figure()

# %%
fig

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.2])  #left,bottom,width,height(range o to 1)

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8]) #left,bottom,width,height(range o to 1)
axes.plot(x,y,'g--')

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8]) #left,bottom,width,height(range o to 1)
axes.plot(x,y,'g--')
axes.set_xlabel("X-axis")
axes.set_ylabel("Y-axis")
axes.set_title("Graph of X vs Y")
# Out:
# Text(0.5, 1.0, 'Graph of X vs Y')

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.2]) #left,bottom,width,height(range o to 1)
axes.plot(x,y,'g--')
axes.set_xlabel("X-axis")
axes.set_ylabel("Y-axis")
axes.set_title("Graph of X vs Y")
# Out:
# Text(0.5, 1.0, 'Graph of X vs Y')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8]) #left,bottom,width,height(range o to 1)
axes2=fig.add_axes([0.1,0.1,0.3,0.5])

axes1.plot(x,y,'g--')
axes1.set_xlabel("X-axis")
axes1.set_ylabel("Y-axis")
axes1.set_title("Graph of X vs Y")

axes2.plot(x,y,'g--')
axes2.set_xlabel("X-axis")
axes2.set_ylabel("Y-axis")
axes2.set_title("Graph of X vs Y")
# Out:
# Text(0.5, 1.0, 'Graph of X vs Y')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8]) #left,bottom,width,height(range o to 1)
axes2=fig.add_axes([0.1,0.1,0.3,0.3])

axes1.plot(x,y,'g--')
axes1.set_xlabel("X-axis")
axes1.set_ylabel("Y-axis")
axes1.set_title("Graph of X vs Y")

axes2.plot(x,y,'r--')
axes2.set_xlabel("X-axis")
axes2.set_ylabel("Y-axis")
axes2.set_title("Graph of X vs Y")
# Out:
# Text(0.5, 1.0, 'Graph of X vs Y')

# %%
#Subplot
plt.subplot(1,2,1)
plt.plot(x,y,"g--")
plt.subplot(1,2,2)
plt.plot(y,x,'r*-')

# %%
fig, axes = plt.subplots()
axes.plot(x,y)
axes.set_xlabel("X")
axes.set_ylabel("Y")
axes.set_title("X Vs Y")
# Out:
# Text(0.5, 1.0, 'X Vs Y')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)
for ax in axes:
ax.plot(x,y,"y--")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_title("Graph of X Vs Y")
fig.tight_layout()

# %%
fig, axes = plt.subplots(figsize=(10,3))
 
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig.savefig("today_plot.png")

# %%
fig.savefig("today_plot1")

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.2,0.5,0.5])

axes.plot(x,x**2)
axes.plot(x,x**3)

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.2,0.5,0.5])
 
axes.plot(x,x**2,label="x**2")
axes.plot(x,x**3,label="x**3")
 
axes.legend()

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.2,0.5,0.5])
 
axes.plot(x,x**2,label="x**2")
axes.plot(x,x**3,label="x**3")
 
axes.legend(loc=1)

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.2,0.5,0.5])
 
axes.plot(x,x**2,label="x**2")
axes.plot(x,x**3,label="x**3")
 
axes.legend(loc=6)

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.2,0.5,0.5])
 
axes.plot(x,x**2,label="x**2")
axes.plot(x,x**3,label="x**3")
 
axes.legend(loc=10)

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, 'b.-') # blue line with dots
ax.plot(x, x**3, 'g--') # green dashed line

# %%
ig, ax = plt.subplots()
 
ax.plot(x, x+1, color="green", alpha=0.9) # half-transparant
ax.plot(x, x+2, color="#8B008B")        # RGB hex code
ax.plot(x, x+3, color="#FF8C00")

# %%
ig, ax = plt.subplots(figsize=(12,6))
 
ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)
 
# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')
 
# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...
 
# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')
 
# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=10, 
markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green")

# %% [markdown]
# # Scatter plot==> relation between two variables

# %%
plt.scatter(x,y)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# # Histogram=>
# to check the shape of the data distribution.

# %%
np.random.randn(100)
# Out:
# array([-0.09682758, -1.5758969 ,  2.18299434,  0.35634801, -0.55101133,
#         0.26438535,  1.00079924,  1.09336781, -1.44356491, -0.6269147 ,
#        -1.60012682,  0.35938117, -0.21227702, -0.45623288, -0.67652706,
#         0.0643822 , -0.86234323, -1.10272011,  0.17395529, -0.58550253,
#         1.13116826,  0.39496456, -0.31140132, -1.18738131,  0.26164364,
#         2.21387506, -0.16790432, -0.25707461,  0.0188789 ,  0.14380628,
#         0.31523576, -1.40846299, -0.23059423, -0.07711692,  1.67951961,
#        -1.42754859,  0.81412116, -0.42609185, -0.79470864,  0.0651616 ,
#        -0.67114257, -1.04628487, -0.85249881, -0.57811213,  1.51421788,
#         0.49742245,  0.34457784,  3.09335361,  2.45124935,  1.40165448,
#         0.01454785, -0.567894  , -1.30808153,  0.2820018 , -2.08749876,
#        -0.61683322, -1.67554783, -0.76692853,  0.3088754 , -0.18990932,
#         1.20439219,  0.24324795,  0.09293121, -1.04614719, -0.40453841,
# ...

# %%
plt.hist(np.random.randint(10,100,50))
# Out:
# (array([5., 8., 6., 3., 4., 5., 5., 4., 5., 5.]),
#  array([12. , 20.6, 29.2, 37.8, 46.4, 55. , 63.6, 72.2, 80.8, 89.4, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([13., 11., 11., 12.,  8.,  6., 10., 13.,  8.,  8.]),
#  array([  1. , 100.7, 200.4, 300.1, 399.8, 499.5, 599.2, 698.9, 798.6,
#         898.3, 998. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
 
fig, ax = plt.subplots()
 
fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']
 
ax.bar(fruits, counts, label=bar_labels, color=bar_colors)
 
ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')
 
plt.show()

# %%
import matplotlib.pyplot as plt
 
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
 
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1be95ae7410>,
# ...
#  [Text(0.9801071672559598, 0.4993895680663527, 'Frogs'),
#   Text(-0.33991877217145816, 1.046162142464278, 'Hogs'),
#   Text(-0.49938947630209474, -0.9801072140121813, 'Dogs'),
#   Text(1.0461621822461364, -0.3399186497354948, 'Logs')])

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import PathPatch
from matplotlib.path import Path

N = 400
t = np.linspace(0, 2 * np.pi, N)
r = 0.5 + np.cos(t)
x, y = r * np.cos(t), r * np.sin(t)

fig, ax = plt.subplots()
ax.plot(x, y, "k")
ax.set(aspect=1)
# Out:
# [None]

# %%
#EDA=> Exploratory Data Analytics
